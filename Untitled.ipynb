# %% [markdown]
# # Pandas
# - Pandas is an open-source library that is made mainly for working with relational or labeled data both easily and intuitively.
# - It provides various data structures and operations for manipulating numerical data and time series.
# - This library is built on top of the NumPy library.
# - Pandas is fast and it has high performance & productivity for users.
# - Pandas generally provide two data structures for manipulating data, They are:
# Series
# - DataFrame

# %%
#importing necessary libraries

# %%
import pandas as Pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # series
# - series is a one-dimensional labelled array and capable of holding data of any type(integer,string,float,python object etc.)

# %%
lst = [1,2,3,4,5]

# %%
lst
# Out:
# [1, 2, 3, 4, 5]

# %%
s=Pd.Series(lst)

# %%
lst
# Out:
# [1, 2, 3, 4, 5]

# %%
type(lst)
# Out:
# list

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s = Pd.Series(data = ['A',1,2,4000])

# %%
s
# Out:
# 0       A
# 1       1
# 2       2
# 3    4000
# dtype: object

# %%
d = {1:'a',2:'b',3:'c'}

type(d)
# Out:
# dict

# %%
s = Pd.Series(d)

# %%
d
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %%
type(d)
# Out:
# dict

# %%
s
# Out:
# 1    a
# 2    b
# 3    c
# dtype: object

# %%
s = Pd.Series(data=[10,20,60],index=['a','b','c'],name='myseries')

# %%
s
# Out:
# a    10
# b    20
# c    60
# Name: myseries, dtype: int64

# %%
#accessing elements from series using index labels

# %%
s[0]
# Out:
# 10

# %%
s['c']
# Out:
# 60

# %% [markdown]
# # Data frame
# - A pandas data frame is a two dimensional data structure, like a two dimensional array or a table with rows and columns
# - ways to create pandas data frame
# - By creating colname or nested list
# - By creating a dictionary.

# %%
lst = [['pune','python',100],['mumbai','ML',84],['hyd','DL',56]]

col = ['city','subject','marks']

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=lst, columns=col)

# %%
df
# Out:
#      city subject  marks
# 0    pune  python    100
# 1  mumbai      ML     84
# 2     hyd      DL     56

# %%
#approach2

# %%
df = pd.DataFrame({
    'subject' : ['python','ML','Dl'],
    'city' : ['mum','hyd','pune'],
    'marks' : [67,70,100]
})

# %%
df
# Out:
#   subject  city  marks
# 0  python   mum     67
# 1      ML   hyd     70
# 2      Dl  pune    100

# %%
#chek number of rows and columns in dataframe

# %%
df.shape
# Out:
# (3, 3)

# %%
#dimension of data frame

# %%
df.ndim
# Out:
# 2

# %%
#datatypes of each column

# %%
df.dtypes
# Out:
# subject    object
# city       object
# marks       int64
# dtype: object

# %%
df.subject
# Out:
# 0    python
# 1        ML
# 2        Dl
# Name: subject, dtype: object

# %%
df
# Out:
#   subject  city  marks
# 0  python   mum     67
# 1      ML   hyd     70
# 2      Dl  pune    100

# %%
df['city']
# Out:
# 0     mum
# 1     hyd
# 2    pune
# Name: city, dtype: object

# %%
#Discriptive stats for Dataframe

# %%
df.describe()
# Out:
#             marks
# count    3.000000
# mean    79.000000
# std     18.248288
# min     67.000000
# 25%     68.500000
# 50%     70.000000
# 75%     85.000000
# max    100.000000

# %%
df.describe(include='all')
# Out:
#        subject city       marks
# count        3    3    3.000000
# unique       3    3         NaN
# top     python  mum         NaN
# freq         1    1         NaN
# mean       NaN  NaN   79.000000
# std        NaN  NaN   18.248288
# min        NaN  NaN   67.000000
# 25%        NaN  NaN   68.500000
# 50%        NaN  NaN   70.000000
# 75%        NaN  NaN   85.000000
# max        NaN  NaN  100.000000

# %%
#getting information about the data frame

# %%
df.info
# Out:
# <bound method DataFrame.info of   subject  city  marks
# 0  python   mum     67
# 1      ML   hyd     70
# 2      Dl  pune    100>

# %%
#checking for null values

# %%
df.isnull().sum()
# Out:
# subject    0
# city       0
# marks      0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of   subject  city  marks
# 0  python   mum     67
# 1      ML   hyd     70
# 2      Dl  pune    100>

# %% [markdown]
# # importing external dataset

# %%
#load the csv file

# %%
df = pd.read_csv(r'C:/Users/acer/Desktop/Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df= pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#reading first five records

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.head(20)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
#reading all the records

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
#describe the data

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.describe(include='all').T
# Out:
#            count unique   top freq           mean           std      min  \
# rank          78      3  Prof   46            NaN           NaN      NaN
# discipline    78      2     B   42            NaN           NaN      NaN
# phd         78.0    NaN   NaN  NaN      19.705128     12.498425      1.0
# service     78.0    NaN   NaN  NaN      15.051282     12.139768      0.0
# sex           78      2  Male   39            NaN           NaN      NaN
# salary      78.0    NaN   NaN  NaN  108023.782051  28293.661022  57800.0
#
#                 25%       50%        75%       max
# rank            NaN       NaN        NaN       NaN
# discipline      NaN       NaN        NaN       NaN
# phd           10.25      18.5      27.75      56.0
# service        5.25      14.5      20.75      51.0
# sex             NaN       NaN        NaN       NaN
# salary      88612.5  104671.0  126774.75  186960.0

# %%
#extracting only columns name

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
#selecting single and multiple columns

# %%
df.phd
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
# 5     20
# 6     20
# 7     18
# 8     29
# 9     51
# 10    39
# 11    23
# 12     1
# 13    35
# 14    25
# 15    17
# 16     8
# 17     4
# 18    19
# 19    29
# 20     4
# 21    33
# 22     4
# 23     2
# 24    30
# 25    35
# 26    38
# 27    45
# 28     7
# 29    21
# 30     9
# 31    22
# 32    27
# 33    18
# 34    12
# 35    28
# 36    45
# 37    20
# 38     4
# 39    18
# 40    39
# 41    13
# 42     4
# 43     5
# 44    23
# 45    25
# 46    11
# 47    11
# 48    17
# 49    17
# 50    10
# 51    20
# 52    12
# 53     5
# 54    25
# 55     2
# 56    10
# 57     3
# 58    36
# 59    12
# 60     3
# 61    13
# 62    14
# 63    29
# 64    26
# 65    36
# 66     7
# 67    17
# 68     4
# 69    28
# 70     8
# 71    12
# 72    24
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, dtype: int64

# %%
df[['phd','salary']]
# Out:
#     phd  salary
# 0    56  186960
# 1    12   93000
# 2    23  110515
# 3    40  131205
# 4    20  104800
# 5    20  122400
# 6    20   81285
# 7    18  126300
# 8    29   94350
# 9    51   57800
# 10   39  128250
# 11   23  134778
# 12    1   88000
# 13   35  162200
# 14   25  153750
# 15   17  150480
# 16    8   75044
# 17    4   92000
# 18   19  107300
# 19   29  150500
# 20    4   92000
# 21   33  103106
# 22    4   73000
# 23    2   85000
# 24   30   91100
# 25   35   99418
# 26   38  148750
# 27   45  155865
# 28    7   91300
# 29   21  123683
# 30    9  107008
# 31   22  155750
# 32   27  103275
# 33   18  120000
# 34   12  119800
# 35   28  126933
# 36   45  146856
# 37   20  102000
# 38    4   91000
# 39   18  129000
# 40   39  137000
# 41   13   74830
# 42    4   80225
# 43    5   77000
# 44   23  151768
# 45   25  140096
# 46   11   74692
# 47   11  103613
# 48   17  111512
# 49   17  122960
# 50   10   97032
# 51   20  127512
# 52   12  105000
# 53    5   73500
# ...

# %%
#selecting columns with loc and iloc

# %%
df.loc[10:15,'phd']
# Out:
# 10    39
# 11    23
# 12     1
# 13    35
# 14    25
# 15    17
# Name: phd, dtype: int64

# %%
df.loc[[10,15],'phd':'salary']
# Out:
#     phd  service   sex  salary
# 10   39       33  Male  128250
# 15   17        3  Male  150480

# %%
df.head(2)
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000

# %%
df.iloc[50:56,1]
# Out:
# 50    B
# 51    B
# 52    A
# 53    A
# 54    A
# 55    A
# Name: discipline, dtype: object

# %%
df.iloc[50:56,0:3]
# Out:
#          rank discipline  phd
# 50   AsstProf          B   10
# 51       Prof          B   20
# 52       Prof          A   12
# 53   AsstProf          A    5
# 54  AssocProf          A   25
# 55   AsstProf          A    2

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
#value counts

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# Male      39
# Female    39
# Name: sex, dtype: int64

# %%
df['discipline'].value_counts()
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
#renaming columns name

# %%
df.rename(columns={'rank':'Rank'})
# Out:
#          Rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
#for permanently renaming them

# %%
df.rename(columns={'discipline':'Discipline','phd':'Phd','salary':'Salary','rank':'Rank'},inplace=True)

# %%
df
# Out:
#          Rank Discipline  Phd  service     sex  Salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...
